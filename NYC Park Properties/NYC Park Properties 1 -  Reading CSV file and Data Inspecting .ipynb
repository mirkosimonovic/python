# %% [markdown]
# Basic and useful Data Analysis using Python of NYC Parks
# Part 1 : Reading and writing CSV file on python
#
# **Goal:** In this notebook, we will (load) and write (save) data from NYC Open Data. Specifically, we will focus on reading our data into a pandas dataframe.
#
# **Main Library:** [pandas](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# Data used for this project its located here (CSV)
#
# https://data.cityofnewyork.us/api/views/n8q6-i44s/rows.csv?accessType=DOWNLOAD&bom=true&format=true
# note: 'we are using a somewhat balanced and clean pre-processed CSV so we dont have to inspect, clean and wrangle mannually this file'
#
# Next to build this project we import the necessaries libraries:

# %%
# importing libraries
import pandas as pd 
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter
import seaborn as sns
from scipy import stats
from numpy import median
sns.color_palette("tab10")

# %% [markdown]
# Next, we proceed to read our CSV File and preview our CSV head data and general info:

# %%
# read data as a dataframe
df = pd.read_csv(r'C:\Users\M\Downloads\NYC_Parks_Structures.csv')

# previewing first five rows in data
df.head()
# Out:
#       Alteration_Year           BBL        BIN borough Comfort Station  \
# 2771              NaN  4.059170e+09  4539831.0      QN           False
# 2772              NaN  4.059170e+09        NaN      QN           False
# 2773              NaN  4.059170e+09  4000000.0      QN           False
# 2774              NaN  4.059170e+09  4539845.0      QN           False
# 2775              NaN  4.059170e+09  4453939.0      QN           False
#
#       CNSTRCT_YR                                        DESCRIPTION  DOITT_ID  \
# 2771         NaN                          Fort Totten Park-Building  827172.0
# 2772         NaN                          Fort Totten Park-Building       NaN
# 2773         NaN                          Fort Totten Park-Building       NaN
# 2774         NaN  Fort Totten Park-Building 342-Swimming Pool Fi...  486282.0
# 2775         NaN                          Fort Totten Park-Building  246576.0
#
#      DOITT_Source  Demolition_Year  ... HEIGHTROOF          LOCATION  MaintBy  \
# 2771      current              NaN  ...       42.0               NaN      NaN
# 2772          NaN              NaN  ...        NaN               NaN      NaN
# 2773          NaN              NaN  ...        NaN               NaN      NaN
# 2774      current              NaN  ...        9.0  342 Story Avenue      NaN
# 2775      current              NaN  ...       34.0               NaN      NaN
#
#      MaintBySpec  OMPPROPID  Parks_District        SYSTEM  \
# 2771         NaN       Q458            Q-07  Q458-BLG0082
# 2772         NaN  Q458-ZN01            Q-07  Q458-BLG0081
# 2773         NaN       Q458            Q-07  Q458-BLG0079
# 2774         NaN       Q458            Q-07  Q458-BLG0078
# 2775         NaN       Q458            Q-07  Q458-BLG0077
#
#                                            multipolygon Recreation_Center  \
# 2771  MULTIPOLYGON (((-73.7751400326344 40.794544083...             False
# 2772  MULTIPOLYGON (((-73.77646199134854 40.79456132...             False
# 2773  MULTIPOLYGON (((-73.77955618031557 40.79495439...             False
# 2774  MULTIPOLYGON (((-73.77436014056161 40.79226430...             False
# 2775  MULTIPOLYGON (((-73.77338091578626 40.78984247...             False
#
#      FeatureStatus
# 2771      Inactive
# 2772      Inactive
# 2773      Inactive
# 2774        Active
# 2775      Inactive
#
# [5 rows x 22 columns]

# %%
# previewing last five rows in data
df.tail()
# Out:
#       Alteration_Year           BBL        BIN borough Comfort Station  \
# 2771              NaN  4.059170e+09  4539831.0      QN           False
# 2772              NaN  4.059170e+09        NaN      QN           False
# 2773              NaN  4.059170e+09  4000000.0      QN           False
# 2774              NaN  4.059170e+09  4539845.0      QN           False
# 2775              NaN  4.059170e+09  4453939.0      QN           False
#
#       CNSTRCT_YR                                        DESCRIPTION  DOITT_ID  \
# 2771         NaN                          Fort Totten Park-Building  827172.0
# 2772         NaN                          Fort Totten Park-Building       NaN
# 2773         NaN                          Fort Totten Park-Building       NaN
# 2774         NaN  Fort Totten Park-Building 342-Swimming Pool Fi...  486282.0
# 2775         NaN                          Fort Totten Park-Building  246576.0
#
#      DOITT_Source  Demolition_Year  ... HEIGHTROOF          LOCATION  MaintBy  \
# 2771      current              NaN  ...       42.0               NaN      NaN
# 2772          NaN              NaN  ...        NaN               NaN      NaN
# 2773          NaN              NaN  ...        NaN               NaN      NaN
# 2774      current              NaN  ...        9.0  342 Story Avenue      NaN
# 2775      current              NaN  ...       34.0               NaN      NaN
#
#      MaintBySpec  OMPPROPID  Parks_District        SYSTEM  \
# 2771         NaN       Q458            Q-07  Q458-BLG0082
# 2772         NaN  Q458-ZN01            Q-07  Q458-BLG0081
# 2773         NaN       Q458            Q-07  Q458-BLG0079
# 2774         NaN       Q458            Q-07  Q458-BLG0078
# 2775         NaN       Q458            Q-07  Q458-BLG0077
#
#                                            multipolygon Recreation_Center  \
# 2771  MULTIPOLYGON (((-73.7751400326344 40.794544083...             False
# 2772  MULTIPOLYGON (((-73.77646199134854 40.79456132...             False
# 2773  MULTIPOLYGON (((-73.77955618031557 40.79495439...             False
# 2774  MULTIPOLYGON (((-73.77436014056161 40.79226430...             False
# 2775  MULTIPOLYGON (((-73.77338091578626 40.78984247...             False
#
#      FeatureStatus
# 2771      Inactive
# 2772      Inactive
# 2773      Inactive
# 2774        Active
# 2775      Inactive
#
# [5 rows x 22 columns]

# %%
#Printing the shape and Dimensions of our dataframe
rows, columns = df.shape
print('This dataset has {:,} rows and {:,} columns.'.format(rows, columns))
# Out:
# This dataset has 2,776 rows and 22 columns.

# %%
# the object's type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# printing the columns of our dataframe in new line
for col in df.columns:
    print(col)
# Out:
# Alteration_Year
# BBL
# BIN
# borough
# Comfort Station
# CNSTRCT_YR
# DESCRIPTION
# DOITT_ID
# DOITT_Source
# Demolition_Year
# GISPROPNUM
# GROUNDELEV
# HEIGHTROOF
# LOCATION
# MaintBy
# MaintBySpec
# OMPPROPID
# Parks_District
# SYSTEM
# multipolygon
# Recreation_Center
# FeatureStatus

# %%
# printing the data types of our columns
df.dtypes
# Out:
# Alteration_Year      float64
# BBL                  float64
# BIN                  float64
# borough               object
# Comfort Station       object
# CNSTRCT_YR           float64
# DESCRIPTION           object
# DOITT_ID             float64
# DOITT_Source          object
# Demolition_Year      float64
# GISPROPNUM            object
# GROUNDELEV           float64
# HEIGHTROOF           float64
# LOCATION              object
# MaintBy              float64
# MaintBySpec          float64
# OMPPROPID             object
# Parks_District        object
# SYSTEM                object
# multipolygon          object
# Recreation_Center     object
# FeatureStatus         object
# dtype: object

# %%
# printing index type
df.index
# Out:
# RangeIndex(start=0, stop=2776, step=1)

# %%
# printing the column names, non-null counts,
# and datatypes of our columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2776 entries, 0 to 2775
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Alteration_Year    42 non-null     float64
#  1   BBL                2675 non-null   float64
#  2   BIN                2447 non-null   float64
#  3   borough            2764 non-null   object
#  4   Comfort Station    2764 non-null   object
#  5   CNSTRCT_YR         1805 non-null   float64
#  6   DESCRIPTION        2579 non-null   object
#  7   DOITT_ID           2281 non-null   float64
#  8   DOITT_Source       2240 non-null   object
#  9   Demolition_Year    0 non-null      float64
#  10  GISPROPNUM         2760 non-null   object
#  11  GROUNDELEV         2234 non-null   float64
#  12  HEIGHTROOF         2164 non-null   float64
#  13  LOCATION           1647 non-null   object
#  14  MaintBy            0 non-null      float64
#  15  MaintBySpec        0 non-null      float64
#  16  OMPPROPID          2720 non-null   object
#  17  Parks_District     2764 non-null   object
#  18  SYSTEM             2764 non-null   object
#  19  multipolygon       2764 non-null   object
#  20  Recreation_Center  2763 non-null   object
#  21  FeatureStatus      2763 non-null   object
# dtypes: float64(10), object(12)
# memory usage: 477.2+ KB
